# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
with open('Streaming_History_Audio_2016-2018_0.json') as json_data0:
    data1618 = json.load(json_data0)
df1618 = pd.DataFrame(data1618)

df1618.head()
# Out:
#                      ts               platform  ms_played conn_country  \
# 0  2016-02-07T18:22:29Z  iOS 9.2.1 (iPhone5,1)     197266           US
# 1  2016-02-07T18:25:41Z  iOS 9.2.1 (iPhone5,1)     192106           US
# 2  2016-02-07T18:26:03Z  iOS 9.2.1 (iPhone5,1)      20852           US
# 3  2016-02-07T18:26:09Z  iOS 9.2.1 (iPhone5,1)       6176           US
# 4  2016-02-07T18:26:10Z  iOS 9.2.1 (iPhone5,1)        371           US
#
#         ip_addr                        master_metadata_track_name  \
# 0  97.99.49.194                                     One Last Time
# 1  97.99.49.194                                      Drag Me Down
# 2  97.99.49.194                                 What Do You Mean?
# 3  97.99.49.194  That's How You Know (feat. Kid Ink & Bebe Rexha)
# 4  97.99.49.194                                     White Iverson
#
#   master_metadata_album_artist_name  \
# 0                     Ariana Grande
# 1                     One Direction
# ...

# %%
with open('Streaming_History_Audio_2018-2019_1.json', encoding='utf-8') as json_data1:
    data1819 = json.load(json_data1)
df1819 = pd.DataFrame(data1819)

df1819.head()
# Out:
#                      ts                            platform  ms_played  \
# 0  2018-08-21T22:10:05Z  Windows 10 (10.0.17134; x64; AppX)          0
# 1  2018-08-21T22:10:05Z  Windows 10 (10.0.17134; x64; AppX)       1980
# 2  2018-08-21T22:10:05Z  Windows 10 (10.0.17134; x64; AppX)         30
# 3  2018-08-21T22:10:05Z  Windows 10 (10.0.17134; x64; AppX)          0
# 4  2018-08-21T22:10:06Z  Windows 10 (10.0.17134; x64; AppX)          0
#
#   conn_country         ip_addr  \
# 0           US  98.156.212.121
# 1           US  98.156.212.121
# 2           US  98.156.212.121
# 3           US  98.156.212.121
# 4           US  98.156.212.121
#
#                          master_metadata_track_name  \
# 0                   I Wanna Know (feat. Bea Miller)
# 1                                         I Like It
# 2  Girls Like You (feat. Cardi B) - Cardi B Version
# 3                                       Jackie Chan
# 4                                   Suit And Jacket
#
# ...

# %%
with open('Streaming_History_Audio_2019-2020_2.json', encoding='utf-8') as json_data2:
    data1920 = json.load(json_data2)
df1920 = pd.DataFrame(data1920)

df1920.head()
# Out:
#                      ts                            platform  ms_played  \
# 0  2019-10-29T02:14:57Z  Windows 10 (10.0.18362; x64; AppX)       2170
# 1  2019-10-29T02:15:00Z  Windows 10 (10.0.18362; x64; AppX)       2560
# 2  2019-10-29T02:18:00Z  Windows 10 (10.0.18362; x64; AppX)     180373
# 3  2019-10-29T02:23:23Z  Windows 10 (10.0.18362; x64; AppX)     212093
# 4  2019-10-29T02:27:04Z  Windows 10 (10.0.18362; x64; AppX)     220866
#
#   conn_country         ip_addr master_metadata_track_name  \
# 0           US  98.156.212.121                  Strangers
# 1           US  98.156.212.121                     Heaven
# 2           US  98.156.212.121        I Don't Wanna Dance
# 3           US  98.156.212.121          Every Single Time
# 4           US  98.156.212.121                  Lookalike
#
#   master_metadata_album_artist_name    master_metadata_album_album_name  \
# 0                    Jonas Brothers                    Happiness Begins
# ...

# %%
with open('Streaming_History_Audio_2020-2021_3.json', encoding='utf-8') as json_data3:
    data2021 = json.load(json_data3)
df2021 = pd.DataFrame(data2021)

df2021.head()
# Out:
#                      ts              platform  ms_played conn_country  \
# 0  2020-10-17T23:08:43Z  iOS 14.0 (iPhone9,1)     177773           US
# 1  2020-10-17T23:12:15Z  iOS 14.0 (iPhone9,1)     211920           US
# 2  2020-10-17T23:15:16Z  iOS 14.0 (iPhone9,1)     180373           US
# 3  2020-10-17T23:18:52Z  iOS 14.0 (iPhone9,1)     215280           US
# 4  2020-10-17T23:22:10Z  iOS 14.0 (iPhone9,1)     197426           US
#
#          ip_addr master_metadata_track_name master_metadata_album_artist_name  \
# 0  99.203.87.238                Silhouettes                      Colony House
# 1  99.203.87.238                Worst Nites                 Foster The People
# 2  99.203.87.238        I Don't Wanna Dance                              COIN
# 3  99.203.87.238                    Circles                       Post Malone
# 4  99.203.87.238               Silvertongue                   Young the Giant
#
# ...

# %%
with open('Streaming_History_Audio_2021_4.json', encoding='utf-8') as json_data4:
    data21 = json.load(json_data4)
df21 = pd.DataFrame(data21)

df21.head()
# Out:
#                      ts                 platform  ms_played conn_country  \
# 0  2021-04-21T21:26:43Z  iOS 14.4.2 (iPhone13,2)     213520           US
# 1  2021-04-21T21:29:40Z  iOS 14.4.2 (iPhone13,2)     176346           US
# 2  2021-04-21T21:30:09Z  iOS 14.4.2 (iPhone13,2)      27580           US
# 3  2021-04-21T21:30:10Z  iOS 14.4.2 (iPhone13,2)       1184           US
# 4  2021-04-21T21:30:16Z  iOS 14.4.2 (iPhone13,2)       5851           US
#
#           ip_addr master_metadata_track_name  \
# 0  172.58.111.234         Let's Kill Tonight
# 1  172.58.111.234             American Idiot
# 2  172.58.111.234              Empty Wallets
# 3  172.58.111.234                  Immortals
# 4  172.58.111.234           Tear in My Heart
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0               Panic! At The Disco                  Vices & Virtues
# 1                         Green Day                   American Idiot
# ...

# %%
with open('Streaming_History_Audio_2021-2022_5.json', encoding='utf-8') as json_data5:
    data2122 = json.load(json_data5)
df2122 = pd.DataFrame(data2122)

df2122.head()
# Out:
#                      ts               platform  ms_played conn_country  \
# 0  2021-09-21T23:03:12Z  iOS 14.8 (iPhone13,2)       5802           US
# 1  2021-09-21T23:03:12Z  iOS 14.8 (iPhone13,2)       1207           US
# 2  2021-09-21T23:03:12Z  iOS 14.8 (iPhone13,2)      52903           US
# 3  2021-09-21T23:03:12Z  iOS 14.8 (iPhone13,2)        960           US
# 4  2021-09-21T23:03:12Z  iOS 14.8 (iPhone13,2)        896           US
#
#           ip_addr master_metadata_track_name  \
# 0  172.58.108.218              Pretty Please
# 1  172.58.108.218              midnight love
# 2  172.58.108.218         Pick Up Your Phone
# 3  172.58.108.218                      Focus
# 4  172.58.108.218                100 Tampons
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                          Dua Lipa                 Future Nostalgia
# 1                       girl in red      if i could make it go quiet
# ...

# %%
with open('Streaming_History_Audio_2022_6.json', encoding='utf-8') as json_data6:
    data22 = json.load(json_data6)
df22 = pd.DataFrame(data22)

df22.head()
# Out:
#                      ts               platform  ms_played conn_country  \
# 0  2022-01-21T23:32:37Z  iOS 15.2 (iPhone13,2)       1184           US
# 1  2022-01-21T23:32:37Z  iOS 15.2 (iPhone13,2)        928           US
# 2  2022-01-21T23:32:44Z  iOS 15.2 (iPhone13,2)       6826           US
# 3  2022-01-21T23:36:05Z  iOS 15.2 (iPhone13,2)     179745           US
# 4  2022-01-21T23:36:05Z  iOS 15.2 (iPhone13,2)        905           US
#
#           ip_addr                    master_metadata_track_name  \
# 0  98.156.196.103                              One More Weekend
# 1  98.156.196.103                                  Pink + White
# 2  98.156.196.103                                       Cloud 9
# 3  98.156.196.103  Where This Flower Blooms (feat. Frank Ocean)
# 4  98.156.196.103                      Kiss Me More (feat. SZA)
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                      Maude Latour                 One More Weekend
# ...

# %%
with open('Streaming_History_Audio_2022-2023_7.json', encoding='utf-8') as json_data7:
    data2223 = json.load(json_data7)
df2223 = pd.DataFrame(data2223)

df2223.head()
# Out:
#                      ts               platform  ms_played conn_country  \
# 0  2022-06-13T09:55:25Z  iOS 15.5 (iPhone13,2)     258000           US
# 1  2022-06-13T09:58:59Z  iOS 15.5 (iPhone13,2)     213336           US
# 2  2022-06-13T10:01:57Z  iOS 15.5 (iPhone13,2)     177600           US
# 3  2022-06-13T10:05:01Z  iOS 15.5 (iPhone13,2)     183074           US
# 4  2022-06-13T10:08:33Z  iOS 15.5 (iPhone13,2)     212013           US
#
#           ip_addr master_metadata_track_name  \
# 0  98.156.196.103   (Only) About Love - Demo
# 1  98.156.196.103                   Godspeed
# 2  98.156.196.103                    Mystery
# 3  98.156.196.103                Lay Me Down
# 4  98.156.196.103                    I THINK
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                        grentperez               Demo(s) About Love
# 1                           Shayhan                         Godspeed
# ...

# %%
with open('Streaming_History_Audio_2023_8.json', encoding='utf-8') as json_data8:
    data23 = json.load(json_data8)
df23 = pd.DataFrame(data23)

df23.head()
# Out:
#                      ts platform  ms_played conn_country        ip_addr  \
# 0  2023-01-14T20:17:53Z      ios     186680           US  172.58.108.45
# 1  2023-01-14T20:24:40Z      ios     406466           US  172.58.108.45
# 2  2023-01-14T20:28:04Z      ios     202826           US  172.58.108.45
# 3  2023-01-14T20:31:38Z      ios     214168           US  172.58.108.45
# 4  2023-01-14T20:34:49Z      ios     189840           US  172.58.108.45
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0     10% (feat. Kali Uchis)                        KAYTRANADA
# 1                    Hold On                      The Internet
# 2             enough for you                    Olivia Rodrigo
# 3                    Pretend                          Bad Suns
# 4                     Woopie                       Still Woozy
#
#            master_metadata_album_album_name  \
# 0                                     BUBBA
# 1                                 Hive Mind
# ...

# %%
with open('Streaming_History_Audio_2023-2024_9.json', encoding='utf-8') as json_data9:
    data2324 = json.load(json_data9)
df2324 = pd.DataFrame(data2324)

df2324.head()
# Out:
#                      ts platform  ms_played conn_country      ip_addr  \
# 0  2023-09-17T08:10:30Z      ios     108237           US  68.51.73.57
# 1  2023-09-17T08:12:24Z      ios     113416           US  68.51.73.57
# 2  2023-09-17T08:14:05Z      ios      99666           US  68.51.73.57
# 3  2023-09-17T08:16:31Z      ios     146000           US  68.51.73.57
# 4  2023-09-17T08:18:20Z      ios     108237           US  68.51.73.57
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0              Swarm of Fish                      Pianopassion
# 1                   Cinnabar                       James Quinn
# 2             Wedding Ballet                    Austin Farwell
# 3                      Solas                    Gibran Alcocer
# 4    Underwater Wonderscapes                  Frederic Bernard
#
#                  master_metadata_album_album_name  \
# 0  Piano Stories III: Inspiration and Enchantment
# 1                                        Cinnabar
# ...

# %%
with open('Streaming_History_Audio_2024-2025_10.json', encoding='utf-8') as json_data10:
    data2425 = json.load(json_data10)
df2425 = pd.DataFrame(data2425)

df2425.head()
# Out:
#                      ts platform  ms_played conn_country  \
# 0  2024-06-03T02:20:16Z      ios     215110           US
# 1  2024-06-03T02:25:37Z      ios     320466           US
# 2  2024-06-03T02:25:47Z      ios       8211           US
# 3  2024-06-03T02:25:48Z      ios       1066           US
# 4  2024-06-03T02:26:00Z      ios      11328           US
#
#                                    ip_addr master_metadata_track_name  \
# 0  2603:8080:7002:3fcc:593d:e084:d6b5:28b1                Show Me How
# 1  2603:8080:7002:3fcc:593d:e084:d6b5:28b1                 Space Song
# 2  2603:8080:7002:3fcc:593d:e084:d6b5:28b1              Over the Moon
# 3  2603:8080:7002:3fcc:593d:e084:d6b5:28b1   Look What You Made Me Do
# 4  2603:8080:7002:3fcc:593d:e084:d6b5:28b1               Them Changes
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                       Men I Trust                      Show Me How
# ...

# %%
with open('Streaming_History_Video_2018-2025.json', encoding='utf-8') as json_data11:
    dataV = json.load(json_data11)
dfV = pd.DataFrame(dataV)

dfV.head()
# Out:
#                      ts                            platform  ms_played  \
# 0  2018-04-09T22:40:49Z                 iOS 9.3.5 (iPad3,1)       1982
# 1  2018-04-09T22:40:52Z                 iOS 9.3.5 (iPad3,1)          0
# 2  2018-04-09T22:40:57Z                 iOS 9.3.5 (iPad3,1)          0
# 3  2018-09-17T00:51:22Z  Windows 10 (10.0.17134; x64; AppX)     240455
# 4  2018-09-17T00:57:01Z  Windows 10 (10.0.17134; x64; AppX)        792
#
#   conn_country         ip_addr master_metadata_track_name  \
# 0           US  76.183.196.214                       None
# 1           US  76.183.196.214                       None
# 2           US  76.183.196.214                       None
# 3           US  98.156.212.121                       None
# 4           US  98.156.212.121                       None
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                              None                             None
# ...

# %%
combined_df_cols = pd.concat([df1618, df1819, df1920, df2021, df21, df2122, df22, df2223, df23, df2324, df2425, dfV], axis=0)
combined_df_cols.info()

combined_df_cols.to_csv("combined.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 168454 entries, 0 to 277
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 168454 non-null  object
#  1   platform                           168454 non-null  object
#  2   ms_played                          168454 non-null  int64
#  3   conn_country                       168454 non-null  object
#  4   ip_addr                            168454 non-null  object
#  5   master_metadata_track_name         167916 non-null  object
#  6   master_metadata_album_artist_name  167916 non-null  object
#  7   master_metadata_album_album_name   167916 non-null  object
#  8   spotify_track_uri                  167916 non-null  object
#  9   episode_name                       533 non-null     object
#  10  episode_show_name                  528 non-null     object
# ...

# %%
dfD = pd.read_csv('combined.csv',encoding='utf-8', low_memory=False)
dfT = pd.read_csv('tate-combined.csv', encoding='utf-8', low_memory=False)
dfD['Person'] = 1
dfT['Person'] = 0

combined_df_cols = pd.concat([dfT,dfD], axis=0)
combined_df_cols.info()

combined_df_cols.to_csv("combinedBig.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 479054 entries, 0 to 168453
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 479054 non-null  object
#  1   platform                           479054 non-null  object
#  2   ms_played                          479054 non-null  int64
#  3   conn_country                       479054 non-null  object
#  4   ip_addr                            479054 non-null  object
#  5   master_metadata_track_name         478396 non-null  object
#  6   master_metadata_album_artist_name  478396 non-null  object
#  7   master_metadata_album_album_name   478396 non-null  object
#  8   spotify_track_uri                  478396 non-null  object
#  9   episode_name                       653 non-null     object
#  10  episode_show_name                  647 non-null     object
# ...
